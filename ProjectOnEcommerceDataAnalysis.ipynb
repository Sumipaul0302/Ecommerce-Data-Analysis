# %% [markdown]
# # **Ecommerce Data Analysis**

# %% [markdown]
# ## **Objective**:

# %% [markdown]
# The objective of this data analysis project is to gain insights into the ecommerce order
# data of a fictional company. We will analyze customer information, product details, and
# order history to derive meaningful conclusions that can aid business decision-making.

# %% [markdown]
# ### Here are some potential analyses we are going to perform:

# %% [markdown]
# ### Customer Analysis:
# ● Identify the total number of customers city wise.
#
# ● Identify the most frequent customers based on their order history.

# %% [markdown]
# ### Product Analysis:
# ● Determine the total number of products available by category.
#
# ● Analyze the distribution of products across sub-categories.
#
# ● Identify products with low stock levels.
#
# ● Calculate the average, maximum, and minimum prices for products.

# %% [markdown]
# ### Order Analysis:
# ● Calculate the top 10 orders product wise.
#
# ● Analyze the order status distribution (e.g., pending, delivered).
#
# ● Identify the most popular products based on order quantity.

# %% [markdown]
# ### Sales Analysis:
# ● Calculate total revenue generated from orders product wise.
#
# ● Calculate the total revenue generated from all orders.
#
# ● Calculate total revenue product category wise percentage.
#
# ● Analyze the performance of different product categories in terms of sales.
#
# ● Identify the most profitable products based on the difference between
# original and selling prices.

# %% [markdown]
# ### Customer Order Patterns:
# ● Identify product names with the highest and lowest order quantities.
#
# ● Identify customers with the highest and lowest order quantities by
# customer name.
#
# ● Determine the most preferred payment modes.

# %% [markdown]
# ### Time-based Analysis:
# ● Month wise total sales.
#
# ● Month and year wise total sales
#
# ● Identify peak order date

# %% [markdown]
# ### Geographical Analysis:
# ● Explore the distribution of customers across different cities.

# %% [markdown]
# ### Product Performance:
# ● Identify the top 10 best-selling products.
#
# ● Identify top 10 slow-moving products based on low sales

# %% [markdown]
# ### Payment Analysis:
# ● Display successful and pending payments order counts.

# %% [markdown]
# ## **Dataset Overview**:

# %% [markdown]
# The dataset consists of three main tables:

# %% [markdown]
# ## customer:
# Contains information about customers, including their ID, name,
# contact details, and address

# %% [markdown]
# CREATE TABLE `customer` (
#
# `customer_id` varchar(10) NOT NULL,
# .`name` varchar(100) NOT NULL,
#
# `city` varchar(65) NOT NULL,
#
# `email` varchar(45) NOT NULL,
#
# `phone_no` varchar(15) NOT NULL,
#
# `address` varchar(100) NOT NULL,
#
# `pin_code` int NOT NULL,
# PRIMARY KEY (`customer_id`)) ;) NOT NULL,
#     -> `pin_code` int NOT NULL,
#     -> PRIMARY KEY (`customer_id`)
#     -> ) ;;

# %% [raw]
# mysql> desc customer;
# +-------------+--------------+------+-----+---------+-------+
# | Field       | Type         | Null | Key | Default | Extra |
# +-------------+--------------+------+-----+---------+-------+
# | customer_id | varchar(10)  | NO   | PRI | NULL    |       |
# | name        | varchar(100) | NO   |     | NULL    |       |
# | city        | varchar(65)  | NO   |     | NULL    |       |
# | email       | varchar(45)  | NO   |     | NULL    |       |
# | phone_no    | varchar(15)  | NO   |     | NULL    |        |
# | address     | varchar(100) | NO   |     | NULL    |       |
# | pin_code    | int          | NO   |     | NULL    |       |
# +-------------+--------------+------+-----+---------+-------+
# 7 rows in set (0.03 sec)

# %% [markdown]
# ## product:
# Contains details about the products available for purchase, including
# product ID, name, category, and pricing.

# %% [markdown]
# CREATE TABLE `product` (
# `product_id` varchar(10) NOT NULL,
#
# `product_name` varchar(100) NOT NULL,
#
# `category` varchar(65) NOT NULL,
#
# `sub_category` varchar(45) NOT NULL,
#
# `original_price` double NOT NULL,
#
# `selling_price` double NOT NULL,
#
# `stock` int NOT NULL,
#
# PRIMARY KEY (`product_id`)
# );)

# %% [raw]
# mysql> desc product;
# +----------------+--------------+------+-----+---------+-------+
# | Field          | Type         | Null | Key | Default | Extra |
# +----------------+--------------+------+-----+---------+-------+
# | product_id     | varchar(10)  | NO   | PRI | NULL    |       |
# | product_name   | varchar(100) | NO   |     | NULL    |       |
# | category       | varchar(65)  | NO   |     | NULL    |       |
# | sub_category   | varchar(45)  | NO   |     | NULL    |       |
# | original_price | double       | NO   |     | NULL    |       |
# | selling_price  | double       | NO   |     | NULL    |       |
# | stock          | int          | NO   |     | NULL    |       |
# +----------------+--------------+------+-----+---------+-------+
# 7 rows in set (0.00 sec)

# %% [markdown]
# ## order_details:
# Captures information about customer orders, including order ID,
# customer ID, product ID, quantity, total price, payment mode, order date, and order
# status.

# %% [markdown]
# CREATE TABLE `order_details` (
#
# `order_id` int NOT NULL AUTO_INCREMENT,
#
# `customer_id` varchar(10) NOT NULL,
#
# `product_id` varchar(10) NOT NULL,
#
# `quantity` double NOT NULL,
#
# `total_price` double NOT NULL,
#
# `payment_mode` varchar(60) NOT NULL,
#
# `order_date` datetime DEFAULT NULL,
#
# `order_status` varchar(20) NOT NULL,
#
# PRIMARY KEY (`order_id`),
#
# KEY `customer_id` (`customer_id`),
#
# KEY `product_id` (`product_id`),
#
# CONSTRAINT `order_details_ibfk_1` FOREIGN KEY (`customer_id`)
#
# REFERENCES `customer` (`customer_id`),
#
# CONSTRAINT `order_details_ibfk_2` FOREIGN KEY (`product_id`)
#
# REFERENCES `product` (`product_id`)
# );
#
# Query OK, 0 rows affected (0.17 sec)d`)
# )

# %% [raw]
# mysql> desc order_details;
# +--------------+-------------+------+-----+---------+----------------+
# | Field        | Type        | Null | Key | Default | Extra          |
# +--------------+-------------+------+-----+---------+----------------+
# | order_id     | int         | NO   | PRI | NULL    | auto_increment |
# | customer_id  | varchar(10) | NO   | MUL | NULL    |                |
# | product_id   | varchar(10) | NO   | MUL | NULL    |                |
# | quantity     | double      | NO   |     | NULL    |                |
# | total_price  | double      | NO   |     | NULL    |                |
# | payment_mode | varchar(60) | NO   |     | NULL    |                |
# | order_date   | datetime    | YES  |     | NULL    |                |
# | order_status | varchar(20) | NO   |     | NULL    |                |
# +--------------+-------------+------+-----+---------+----------------+
# 8 rows in set (0.01 sec)

# %% [markdown]
# ## Step to be perform:

# %% [markdown]
# ## **Database Connectivity**:

# %% [markdown]
# ### To perform the analysis, we'll establish a connection to the MySQL database containing the ecommerce data. We'll use the appropriate Python libraries, such as pandas and mysql, to fetch and manipulate the data directly from the database.

# %%
import mysql.connector
def mydbconnect():
     mydb = mysql.connector.connect (  
     host="localhost",
     user="root",
     password="root",
     database="Ecommerceproject"
      ) 
     return mydb

# %%
mydb=mydbconnect()
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM Customer ")

myresult = mycursor.fetchall()
 
for x in myresult:  
  print(x) 
 
mydb.close()
# Out:
# ('CUST001', 'Rahul Sharma', 'Kolkata', 'rahul.sharma@example.com', '9876543210', '123 Main Street', 110001)
# ('CUST002', 'Priya Patel', 'Mumbai', 'priya.patel@example.com', '8765432109', '456 Market Road', 400001)
# ('CUST003', 'Amit Singh', 'Kolkata', 'amit.singh@example.com', '7654321098', '789 Park Avenue', 700001)
# ('CUST004', 'Ananya Das', 'Chennai', 'ananya.das@example.com', '6543210987', '101 Galaxy Street', 600001)
# ('CUST005', 'Sandeep Verma', 'Mumbai', 'sandeep.verma@example.com', '5432109876', '222 Tech Lane', 560001)
# ('CUST006', 'Neha Kapoor', 'Chennai', 'neha.kapoor@example.com', '4321098765', '333 Innovator Road', 500001)
# ('CUST007', 'Vikram Yadav', 'Delhi', 'vikram.yadav@example.com', '3210987654', '444 Startup Street', 380001)
# ('CUST008', 'Pooja Reddy', 'Pune', 'pooja.reddy@example.com', '2109876543', '555 Venture Avenue', 411001)
# ('CUST009', 'Raj Malhotra', 'Jaipur', 'raj.malhotra@example.com', '1098765432', '666 Opportunity Lane', 302001)
# ...

# %%
mydb=mydbconnect()
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM Product")

myresult = mycursor.fetchall()

for x in myresult: 
  print(x)

mydb.close()
# Out:
# ('PROD001', 'Laptop', 'Electronics', 'Computers', 400000.0, 32000.0, 50)
# ('PROD002', 'Smartphone', 'Electronics', 'Mobiles', 300000.0, 25000.0, 100)
# ('PROD003', 'LED TV', 'Electronics', 'Televisions', 29990.0, 20500.0, 30)
# ('PROD004', 'Coffee Maker', 'Appliances', 'Kitchen Appliances', 2000.0, 1800.0, 75)
# ('PROD005', 'Running Shoes', 'Fashion', 'Footwear', 2500.0, 1400.0, 200)
# ('PROD006', 'Backpack', 'Fashion', 'Bags', 2000.0, 1200.0, 150)
# ('PROD007', 'Digital Camera', 'Electronics', 'Cameras', 7500.0, 6550.0, 20)
# ('PROD008', 'Office Chair', 'Furniture', 'Chairs', 4500.0, 3000.0, 50)
# ('PROD009', 'Microwave Oven', 'Appliances', 'Kitchen Appliances', 7000.0, 5000.0, 40)
# ('PROD010', 'Fitness Tracker', 'Electronics', 'Wearable Tech', 3500.0, 2500.0, 80)

# %%
mydb=mydbconnect()
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM order_details")

myresult = mycursor.fetchall()

for x in myresult: 
  print(x)

mydb.close()
# Out:
# (1, 'CUST005', 'PROD001', 2.0, 4500.0, 'Credit Card', datetime.datetime(2020, 5, 30, 4, 25), 'Shipped')
# (2, 'CUST002', 'PROD002', 3.0, 114000.0, 'PayPal', datetime.datetime(2022, 4, 20, 1, 25, 1), 'Processing')
# (3, 'CUST004', 'PROD003', 1.0, 20500.0, 'Credit Card', datetime.datetime(2022, 12, 20, 4, 14, 20), 'Delivered')
# (4, 'CUST010', 'PROD004', 5.0, 15000.0, 'Cash on Delivery', datetime.datetime(2021, 2, 10, 14, 5, 20), 'Shipped')
# (5, 'CUST005', 'PROD005', 2.0, 7500.0, 'Credit Card', datetime.datetime(2020, 12, 20, 7, 15), 'Processing')
# (6, 'CUST004', 'PROD006', 4.0, 10000.0, 'Credit Card', datetime.datetime(2022, 1, 25, 0, 0), 'Delivered')
# (7, 'CUST006', 'PROD007', 1.0, 2000.0, 'PayPal', datetime.datetime(2020, 9, 10, 1, 14), 'Shipped')
# (8, 'CUST001', 'PROD008', 2.0, 4500.0, 'Credit Card', datetime.datetime(2021, 6, 5, 1, 15, 30), 'Processing')
# (9, 'CUST002', 'PROD009', 3.0, 5000.0, 'Cash on Delivery', datetime.datetime(2021, 6, 4, 1, 15, 30), 'Delivered')
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb=mydbconnect() 
sqlstmt="select *  from Customer" 
sql_query = pd.read_sql_query(sqlstmt,mydb)

df = pd.DataFrame(sql_query, columns = ['customer_id','name ','city','email','phone_no','address','pin_code'])
print(df.head())
# Out:
#   customer_id  name      city                      email    phone_no  \
# 0     CUST001    NaN  Kolkata   rahul.sharma@example.com  9876543210
# 1     CUST002    NaN   Mumbai    priya.patel@example.com  8765432109
# 2     CUST003    NaN  Kolkata     amit.singh@example.com  7654321098
# 3     CUST004    NaN  Chennai     ananya.das@example.com  6543210987
# 4     CUST005    NaN   Mumbai  sandeep.verma@example.com  5432109876
#
#              address  pin_code
# 0    123 Main Street    110001
# 1    456 Market Road    400001
# 2    789 Park Avenue    700001
# 3  101 Galaxy Street    600001
# 4      222 Tech Lane    560001
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\4284544652.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt,mydb)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb=mydbconnect() 
sqlstmt="select *  from Product" 
sql_query = pd.read_sql_query(sqlstmt,mydb)

df = pd.DataFrame(sql_query, columns = ['product_id','product_name',' category','sub_category','original_price','selling_price','stock'])
print(df.head())
# Out:
#   product_id   product_name   category        sub_category  original_price  \
# 0    PROD001         Laptop        NaN           Computers        400000.0
# 1    PROD002     Smartphone        NaN             Mobiles        300000.0
# 2    PROD003         LED TV        NaN         Televisions         29990.0
# 3    PROD004   Coffee Maker        NaN  Kitchen Appliances          2000.0
# 4    PROD005  Running Shoes        NaN            Footwear          2500.0
#
#    selling_price  stock
# 0        32000.0     50
# 1        25000.0    100
# 2        20500.0     30
# 3         1800.0     75
# 4         1400.0    200
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\219170329.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt,mydb)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb=mydbconnect()
sqlstmt="select *  from Order_details" 
sql_query = pd.read_sql_query(sqlstmt,mydb)

df = pd.DataFrame(sql_query, columns = ['order_id','customer_id','product_id',' quantity','total_price','payment_mode','order_date','order_status'])
print(df.head())
# Out:
#    order_id customer_id product_id   quantity  total_price      payment_mode  \
# 0         1     CUST005    PROD001        NaN       4500.0       Credit Card
# 1         2     CUST002    PROD002        NaN     114000.0            PayPal
# 2         3     CUST004    PROD003        NaN      20500.0       Credit Card
# 3         4     CUST010    PROD004        NaN      15000.0  Cash on Delivery
# 4         5     CUST005    PROD005        NaN       7500.0       Credit Card
#
#            order_date order_status
# 0 2020-05-30 04:25:00      Shipped
# 1 2022-04-20 01:25:01   Processing
# 2 2022-12-20 04:14:20    Delivered
# 3 2021-02-10 14:05:20      Shipped
# 4 2020-12-20 07:15:00   Processing
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\3090870774.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# ...

# %% [markdown]
# ## Description:

# %% [markdown]
# customer_data = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
# cursor.description])

# %% [markdown]
# ### cursor.fetchall():
# This part of the code fetches all the rows from the result set obtained
# from a database query using the cursor object. The fetchall() method retrieves all the
# rows as a list of tuples.

# %% [markdown]
# ### columns
# =[desc[0] for desc in cursor.description]: This part creates a list of column
# names for the DataFrame. It uses a list comprehension to iterate over thecursor.description, which is a list of 7-item tuples describing the columns in the result
# set. The [desc[0] for desc in cursor.description] extracts the first element (column
# name) from each tuple in the cursor.description and creates a list of column names.

# %% [markdown]
# ### pd.DataFrame(...):
# This part creates a Pandas DataFrame using the pd.DataFrame()
# constructor. It takes the fetched data (result of the query) and the list of column names
# as arguments. The DataFrame is assigned to the variable customer_data.
# In summary, this line of code fetches data from a database using a cursor, extracts
# column names from the cursor description, and creates a Pandas DataFrame with the
# fetched data and column names. The resulting DataFrame (customer_data) can be used
# for further analysis or manipulation using Pandas functionalities.

# %% [markdown]
# ## Data Cleaning:
# Before proceeding with the analysis, let's perform some basic data cleaning
# :
# ● Check for missing values in each tabl
#   e  .
# ● Ensure data types are appropriate for each colu
#   m  n.
# ● Handle any outliers or inconsistencies

# %% [markdown]
# ### Check for missing values in each table

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb=mydbconnect()
sqlstmt="select *  from customer" 
sql_query = pd.read_sql_query(sqlstmt,mydb)
print("Missing values in each column:")
print(df.isnull().sum())
print("\nData types for each column:")
print(df.dtypes)
# Out:
# Missing values in each column:
# order_id         0
# customer_id      0
# product_id       0
#  quantity       10
# total_price      0
# payment_mode     0
# order_date       0
# order_status     0
# dtype: int64
#
# Data types for each column:
# order_id                 int64
# customer_id             object
# product_id              object
#  quantity              float64
# total_price            float64
# payment_mode            object
# order_date      datetime64[ns]
# order_status            object
# dtype: object
# C:\Users\Personal\AppData\Local\Temp\ipykernel_12356\1793462515.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt,mydb)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb=mydbconnect()
sqlstmt="select *  from product" 
sql_query = pd.read_sql_query(sqlstmt,mydb)
print("Missing values in each column:")
print(df.isnull().sum())
print("\nData types for each column:")
print(df.dtypes)
# Out:
# Missing values in each column:
# order_id         0
# customer_id      0
# product_id       0
#  quantity       10
# total_price      0
# payment_mode     0
# order_date       0
# order_status     0
# dtype: int64
#
# Data types for each column:
# order_id                 int64
# customer_id             object
# product_id              object
#  quantity              float64
# total_price            float64
# payment_mode            object
# order_date      datetime64[ns]
# order_status            object
# dtype: object
# C:\Users\Personal\AppData\Local\Temp\ipykernel_12356\521689937.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt,mydb)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb=mydbconnect()
sqlstmt="select *  from order_details" 
sql_query = pd.read_sql_query(sqlstmt,mydb)
print("Missing values in each column:")
print(df.isnull().sum())
print("\nData types for each column:")
print(df.dtypes)
# Out:
# Missing values in each column:
# order_id         0
# customer_id      0
# product_id       0
#  quantity       10
# total_price      0
# payment_mode     0
# order_date       0
# order_status     0
# dtype: int64
#
# Data types for each column:
# order_id                 int64
# customer_id             object
# product_id              object
#  quantity              float64
# total_price            float64
# payment_mode            object
# order_date      datetime64[ns]
# order_status            object
# dtype: object
# C:\Users\Personal\AppData\Local\Temp\ipykernel_12356\2439837885.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt,mydb)

# %% [markdown]
# ## Exploratory Data Analysis (EDA) and Visualization:

# %% [markdown]
# ### ● Customer Analysis:

# %% [markdown]
# ###  Identify the total number of customers City wise.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb=mydbconnect()
sqlstmt="select *  from customer" 
sql_query = pd.read_sql_query(sqlstmt,mydb)

df = pd.DataFrame(sql_query, columns = ['customer_id','name ','city','email','phone_no','address','pin_code'])
# Count the number of customers city-wise
city_wise_customer_count = df['city'].value_counts()

# Print the city-wise customer count
print(city_wise_customer_count) 

# Plotting city-wise customer count
city_wise_customer_count.plot(kind='bar', color='purple', figsize=(10,6))
plt.title('Number of Customers City-wise')
plt.xlabel('City')
plt.ylabel('Number of Customers')
plt.show()
# Out:
# city
# Mumbai     3
# Kolkata    2
# Chennai    2
# Delhi      1
# Pune       1
# Jaipur     1
# Name: count, dtype: int64
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\1433937902.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt,mydb)

# %% [markdown]
# ### Identify the most frequent customers based on their order history.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb=mydbconnect()
sqlstmt="select *  from order_details" 
sql_query = pd.read_sql_query(sqlstmt,mydb)

df = pd.DataFrame(sql_query, columns = ['order_id', 'customer_id', 'product_id', 'quantity', 'total_price', 'payment_mode', 'order_date', 'order_status'
])
# Count the number of orders for each customer
customer_order_counts = df['customer_id'].value_counts()

# Print the customer order counts
print(customer_order_counts)

# Plotting customer order counts
customer_order_counts.plot(kind='bar', color='teal', figsize=(10,6))
plt.title('Number of Orders for Each Customer') 
plt.xlabel('Customer ID')
plt.ylabel('Number of Orders')
plt.show()
# Out:
# customer_id
# CUST005    2
# CUST002    2
# CUST004    2
# CUST006    2
# CUST010    1
# CUST001    1
# Name: count, dtype: int64
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\225607938.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt,mydb)

# %% [markdown]
# ## ● Product Analysis:

# %% [markdown]
# ### Determine the total number of products available by category.

# %%
mydb=mydbconnect()
mycursor = mydb.cursor()
# Query data from the 'product' table 
mycursor.execute('SELECT * FROM product')
product_data = pd.DataFrame(mycursor.fetchall(), columns=[desc[0] for desc in
mycursor.description])

# %%
product_data.groupby('category')['product_id'].count().sort_values(ascending=False).plot(kind='bar',xlabel='Category',ylabel='Number of occurrences',title='Distribution of Products',color=['blue','orange','purple','brown'])
# Out:
# <Axes: title={'center': 'Distribution of Products'}, xlabel='Category', ylabel='Number of occurrences'>

# %% [markdown]
# ### Calculate the average, maximum, and minimum selling prices for products.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb=mydbconnect()
sqlstmt="select *  from product" 
sql_query = pd.read_sql_query(sqlstmt,mydb)

df = pd.DataFrame(sql_query, columns = ['product_id','product_name',' category ','sub_category',' original_price','selling_price','stock'])
average_price = df['selling_price'].mean()
maximum_price = df['selling_price'].max()
minimum_price = df['selling_price'].min()

# Print the results
print(f'Average Selling Price: {average_price}')
print(f'Maximum Selling Price: {maximum_price}')
print(f'Minimum Selling Price: {minimum_price}')

plt.figure(figsize=(10, 6))
plt.bar(['Average', 'Maximum', 'Minimum'], [average_price, maximum_price, minimum_price])
plt.title('Average, Maximum, and Minimum Selling Prices')
plt.xlabel('Statistic')
plt.ylabel('Selling Price')
plt.show()
# Out:
# Average Selling Price: 9895.0
# Maximum Selling Price: 32000.0
# Minimum Selling Price: 1200.0
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\776585386.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt,mydb)

# %% [markdown]
# ## ● Order Analysis:

# %% [markdown]
# ### Calculate the top 10 orders product wise.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 

mydb=mydbconnect()
sqlstmt="select o.order_id,o.quantity,p.product_name from product p natural join order_details o" 
sql_query = pd.read_sql_query(sqlstmt,mydb)

df = pd.DataFrame(sql_query, columns = ['order_id',  'product_name', 'quantity'])
df.groupby('product_name')['order_id'].sum().sort_values(ascending=False).plot(kind='bar',xlabel='Product Name',ylabel='Number of Orders',title='Total Number of Orders Product Wise with Product Name',color='blue')
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\1082941110.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt,mydb)
# <Axes: title={'center': 'Total Number of Orders Product Wise with Product Name'}, xlabel='Product Name', ylabel='Number of Orders'>

# %% [markdown]
# ### Analyze the order status distribution (e.g., pending, delivered).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb=mydbconnect()
sqlstmt="select * from order_details" 
sql_query = pd.read_sql_query(sqlstmt,mydb)

df = pd.DataFrame(sql_query, columns = ['order_id',  'order_status', 'quantity'])
df.groupby('order_status')['order_id'].sum().sort_values(ascending=False).plot(kind='bar',xlabel='Product Name',ylabel='Number of Orders',title='Order Status Distribution',color='brown')
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\1979974797.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt,mydb)
# <Axes: title={'center': 'Order Status Distribution'}, xlabel='Product Name', ylabel='Number of Orders'>

# %% [markdown]
# ### Identify the most popular products based on order quantity.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb=mydbconnect()
sqlstmt="select o.order_id,o.quantity,p.product_name from product p natural join order_details o" 
sql_query = pd.read_sql_query(sqlstmt,mydb)

df = pd.DataFrame(sql_query, columns = ['order_id',  'product_name', 'quantity'])
df.groupby('product_name')['quantity'].sum().sort_values(ascending=False).head(10).plot(kind='bar',xlabel='Product Name',ylabel='Number of Orders',title='Top 10 Most Popular Products based on order Quantity',color='violet')
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\336466690.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt,mydb)
# <Axes: title={'center': 'Top 10 Most Popular Products based on order Quantity'}, xlabel='Product Name', ylabel='Number of Orders'>

# %% [markdown]
# ## ● Sales Analysis:

# %% [markdown]
# ### Calculate total revenue generated from orders product wise

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
 
mydb = mydbconnect()
sqlstmt = "select o.order_id, o.quantity, p.product_name, p. selling_price from product p natural join order_details o" 
sql_query = pd.read_sql_query(sqlstmt, mydb) 

df = pd.DataFrame(sql_query, columns = ['order_id', 'product_name', 'quantity', 'selling_price'])
df['revenue'] = df['quantity'] * df['selling_price']
df.groupby('product_name')['revenue'].sum().sort_values(ascending=False).plot(kind='bar', xlabel='Product Name', ylabel='Total Revenue', title='Total Revenue Generated from Orders Product Wise', color='pink')
plt.show()
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\3038149759.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt, mydb)

# %% [markdown]
# ### Calculate total revenue product category wise percentage.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb = mydbconnect()
sqlstmt = "select o.order_id, o.quantity, p.product_name, p.selling_price, p.category from product p natural join order_details o" 
sql_query = pd.read_sql_query(sqlstmt, mydb)

df = pd.DataFrame(sql_query, columns = ['order_id', 'product_name', 'quantity', 'selling_price', 'category'])
df['revenue'] = df['quantity'] * df['selling_price']
revenue_by_category = df.groupby('category')['revenue'].sum()
total_revenue = revenue_by_category.sum()
revenue_percentage = (revenue_by_category / total_revenue) * 100
 
revenue_percentage.plot(kind='pie', autopct='%1.1f%%')
plt.title('Total Revenue Generated from Orders Category Wise (in percentage)')
plt.ylabel('')
plt.show()
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\1267400903.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt, mydb)

# %% [markdown]
# ### Calculate the total revenue generated from all orders

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb = mydbconnect()
sqlstmt = "select o.order_id, o.quantity, p.product_name, p.selling_price from product p natural join order_details o" 
sql_query = pd.read_sql_query(sqlstmt, mydb)

df = pd.DataFrame(sql_query, columns = ['order_id', 'product_name', 'quantity', 'selling_price'])
df['revenue'] = df['quantity'] * df['selling_price']
total_revenue = df['revenue'].sum()
 
plt.bar('Total Revenue', total_revenue, color='blue')
plt.xlabel('Order')
plt.ylabel('Total Revenue')
plt.title('Total Revenue Generated from All Orders')
plt.show()
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\763881400.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt, mydb)

# %% [markdown]
# ### Identify the most profitable products based on the difference between original and selling prices.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb = mydbconnect()
sqlstmt = "select o.order_id, o.quantity, p.product_name, p.selling_price, p.original_price from product p natural join order_details o" 
sql_query = pd.read_sql_query(sqlstmt, mydb)

df = pd.DataFrame(sql_query, columns = ['order_id', 'product_name', 'quantity', 'selling_price', 'original_price'])
df['profit'] = df['quantity'] * (df['selling_price'] - df['original_price'])
profit_by_product = df.groupby('product_name')['profit'].sum().sort_values(ascending=False)

profit_by_product.plot(kind='bar', xlabel='Product Name', ylabel='Profit', title='Profit Generated from Each Product', color='purple')
plt.show()
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\3365453702.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt, mydb)

# %% [markdown]
# ## ● Customer Order Patterns:

# %% [markdown]
# ### Identify product names with the highest and lowest order quantities.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb = mydbconnect()
sqlstmt = "select o.order_id, o.quantity, p.product_name from product p natural join order_details o" 
sql_query = pd.read_sql_query(sqlstmt, mydb) 

df = pd.DataFrame(sql_query, columns = ['order_id', 'product_name', 'quantity'])
quantity_by_product = df.groupby('product_name')['quantity'].sum().sort_values(ascending=False)

# Product with highest order quantity
highest_quantity_product = quantity_by_product.idxmax()
print(f"The product with the highest order quantity is: {highest_quantity_product}")

# Product with lowest order quantity
lowest_quantity_product = quantity_by_product.idxmin()
print(f"The product with the lowest order quantity is: {lowest_quantity_product}")

# Plotting the products with highest and lowest order quantities
quantity_by_product[[highest_quantity_product, lowest_quantity_product]].plot(kind='bar', xlabel='Product Name', ylabel='Order Quantity', title='Order Quantity for Products with Highest and Lowest Quantities', color=['skyblue', 'teal'])
plt.show()
# Out:
# The product with the highest order quantity is: Coffee Maker
# The product with the lowest order quantity is: Digital Camera
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\1798485626.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt, mydb)

# %% [markdown]
# ### Identify customers with the highest and lowest order quantities by customer name.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb = mydbconnect()
sqlstmt = "select o.order_id, o.quantity, c.name from customer c natural join order_details o" 
sql_query = pd.read_sql_query(sqlstmt, mydb)

df = pd.DataFrame(sql_query, columns = ['order_id', 'name', 'quantity'])
quantity_by_customer = df.groupby('name')['quantity'].sum().sort_values(ascending=False)

# Customer with highest order quantity
highest_quantity_customer = quantity_by_customer.idxmax()
print(f"The customer with the highest order quantity is: {highest_quantity_customer}")

# Customer with lowest order quantity
lowest_quantity_customer = quantity_by_customer.idxmin()
print(f"The customer with the lowest order quantity is: {lowest_quantity_customer}")

# Plotting the customers with highest and lowest order quantities
quantity_by_customer[[highest_quantity_customer, lowest_quantity_customer]].plot(kind='bar', xlabel='Customer Name', ylabel='Order Quantity', title='Order Quantity for Customers with Highest and Lowest Quantities', color=['purple', 'teal'])
plt.show()
# Out:
# The customer with the highest order quantity is: Priya Patel
# The customer with the lowest order quantity is: Neha Kapoor
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\2424903387.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt, mydb)

# %% [markdown]
# ### Determine the most preferred payment modes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

mydb = mydbconnect()
sqlstmt = "select o.order_id, o.payment_mode from order_details o" 
sql_query = pd.read_sql_query(sqlstmt, mydb)

df = pd.DataFrame(sql_query, columns = ['order_id', 'payment_mode'])
payment_mode_counts = df['payment_mode'].value_counts()

# Plotting the payment modes
payment_mode_counts.plot(kind='bar', xlabel='Payment Mode', ylabel='Number of Orders', title='Number of Orders for Each Payment Mode', color='red')
plt.show()
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\569561643.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt, mydb)

# %% [markdown]
# ## ● Time-based Analysis:

# %% [markdown]
# ### Month wise total sales.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import calendar

mydb = mydbconnect()
sqlstmt = "select o.order_id, o.order_date, o.quantity, p.product_name, p.selling_price from product p natural join order_details o" 
sql_query = pd.read_sql_query(sqlstmt, mydb)

df = pd.DataFrame(sql_query, columns = ['order_id', 'order_date', 'product_name', 'quantity', 'selling_price'])
df['order_date'] = pd.to_datetime(df['order_date'])  # Convert order_date to datetime
df['month'] = df['order_date'].dt.month  # Extract month from order_date
df['month'] = df['month'].apply(lambda x: calendar.month_name[x])  # Convert month number to month name

df['revenue'] = df['quantity'] * df['selling_price']
df_monthly_revenue = df.groupby('month')['revenue'].sum()  # Group by month and calculate total revenue

colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']  # Define a list of colors
plt.bar(df_monthly_revenue.index, df_monthly_revenue, color=colors)
plt.xlabel('Month') 
plt.ylabel('Total Revenue') 
plt.title('Month-wise Total Revenue Generated from All Orders')
plt.show()
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\618374392.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt, mydb)

# %% [markdown]
# ### Month and year wise total sales

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import calendar

mydb = mydbconnect()
sqlstmt = "select o.order_id, o.order_date, o.quantity, p.product_name, p.selling_price from product p natural join order_details o" 
sql_query = pd.read_sql_query(sqlstmt, mydb)

df = pd.DataFrame(sql_query, columns = ['order_id', 'order_date', 'product_name', 'quantity', 'selling_price'])
df['order_date'] = pd.to_datetime(df['order_date'])  # Convert order_date to datetime
df['month_year'] = df['order_date'].dt.to_period('M')  # Extract month and year from order_date
df['month_year'] = df['month_year'].apply(lambda x: x.strftime('%B-%Y'))  # Convert month number to month name and concatenate with year

df['revenue'] = df['quantity'] * df['selling_price']
df_monthly_revenue = df.groupby('month_year')['revenue'].sum()  # Group by month and year and calculate total revenue

colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']  # Define a list of colors
colors = colors * (len(df_monthly_revenue) // len(colors)) + colors[:len(df_monthly_revenue) % len(colors)]  # Repeat colors if necessary

plt.bar(df_monthly_revenue.index, df_monthly_revenue, color=colors)
plt.xlabel('Month and Year') 
plt.ylabel('Total Revenue')
plt.title('Month and Year-wise Total Revenue Generated from All Orders')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.show()
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\339478854.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt, mydb)

# %% [markdown]
# ### Identify peak order date

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import calendar

mydb = mydbconnect()
sqlstmt = "select o.order_id, o.order_date, o.quantity, p.product_name, p.selling_price from product p natural join order_details o" 
sql_query = pd.read_sql_query(sqlstmt, mydb)

df = pd.DataFrame(sql_query, columns = ['order_id', 'order_date', 'product_name', 'quantity', 'selling_price'])
df['order_date'] = pd.to_datetime(df['order_date'])  # Convert order_date to datetime

df_order_count = df.groupby('order_date')['order_id'].count()  # Group by order_date and count the number of orders

peak_order_date = df_order_count.idxmax()  # Identify the date with the highest number of orders

print(f"The peak order date is {peak_order_date.strftime('%B %d, %Y')}, with a total of {df_order_count[peak_order_date]} orders")

# Plotting the trend graph 
plt.figure(figsize=(10, 5))
plt.plot(df_order_count.index, df_order_count, color='brown')
plt.xlabel('Order Date')
plt.ylabel('Number of Orders')
plt.title('Trend of Number of Orders Over Time')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\54069140.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt, mydb)
# The peak order date is January 25, 2022, with a total of 2 orders

# %% [markdown]
# ## Geographical Analysis:

# %% [markdown]
# ### Explore the distribution of customers across different cities.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

mydb = mydbconnect()
sqlstmt = "select o.order_id, o.customer_id, p.product_name, p.category, c.city from product p natural join order_details o join customer c on o.customer_id = c.customer_id" 
sql_query = pd.read_sql_query(sqlstmt, mydb)

df = pd.DataFrame(sql_query, columns = ['order_id', 'customer_id', 'product_name', 'category', 'city'])

df_product_distribution = df.groupby(['city', 'category'])['order_id'].count().unstack()  # Count the number of orders for each category from each city

plt.figure(figsize=(10, 5))
sns.heatmap(df_product_distribution, cmap='viridis', annot=True, fmt='.2f')  # Use the 'viridis' colormap
plt.xlabel('Category')
plt.ylabel('City') 
plt.title('Distribution of Product Categories Across Different Cities')
plt.show()
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\4069563906.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt, mydb)

# %% [markdown]
# ## ● Product Performance:

# %% [markdown]
# ### Identify the best-selling products.

# %%
import pandas as pd
import matplotlib.pyplot as plt

mydb = mydbconnect()
sqlstmt = "SELECT p.product_name, SUM(o.quantity) as total_quantity FROM product p NATURAL JOIN order_details o JOIN customer c ON o.customer_id = c.customer_id GROUP BY p.product_name ORDER BY total_quantity DESC LIMIT 10" 
sql_query = pd.read_sql_query(sqlstmt, mydb)

df = pd.DataFrame(sql_query, columns = ['product_name', 'total_quantity'])

plt.figure(figsize=(10, 5))
plt.bar(df['product_name'], df['total_quantity'])
plt.xlabel('Product Name')
plt.ylabel('Total Quantity Ordered')
plt.title('Top 10 Best-Selling Products') 
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.show()
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\3351761332.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt, mydb)

# %% [markdown]
# ### Identify top 10 slow-moving products based on low sales.

# %%
import pandas as pd
import matplotlib.pyplot as plt

mydb = mydbconnect()
sqlstmt = "SELECT p.product_name, SUM(o.quantity) as total_quantity FROM product p NATURAL JOIN order_details o JOIN customer c ON o.customer_id = c.customer_id GROUP BY p.product_name ORDER BY total_quantity ASC LIMIT 10" 
sql_query = pd.read_sql_query(sqlstmt, mydb)

df = pd.DataFrame(sql_query, columns = ['product_name', 'total_quantity'])

plt.figure(figsize=(10, 5))
plt.bar(df['product_name'], df['total_quantity'])
plt.xlabel('Product Name')
plt.ylabel('Total Quantity Ordered') 
plt.title('Top 10 Slow-Moving Products')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.show()
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\2708728752.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt, mydb)

# %% [markdown]
# ## ● Payment Analysis:

# %% [markdown]
# ### Display successful and pending payments order counts.

# %%
import pandas as pd
import matplotlib.pyplot as plt

mydb = mydbconnect()
sqlstmt = "SELECT o.order_status, COUNT(o.order_id) as number_of_orders FROM order_details o WHERE o.order_status IN ('Delivered', 'Processing','Shipped') GROUP BY o.order_status" 
sql_query = pd.read_sql_query(sqlstmt, mydb)

df = pd.DataFrame(sql_query, columns = ['order_status', 'number_of_orders'])

# Define a color map
color_map = {'Delivered': 'green', 'Processing': 'orange', 'Shipped': 'purple'}

plt.figure(figsize=(10, 5))
# Use the color map for the bars
plt.bar(df['order_status'], df['number_of_orders'], color=[color_map[i] for i in df['order_status']])
plt.xlabel('Order Status')
plt.ylabel('Number of Orders')
plt.title('Number of Orders by Order Status')
plt.show()
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_16080\4149344748.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_query = pd.read_sql_query(sqlstmt, mydb)

# %% [markdown]
# ## **Conclusion**:

# %% [markdown]
# ## ● Customer Analysis:
#
# ### Total number of customers City wise.
# The bar graph titled “Number of Customers City-wise” shows that Mumbai has the highest customer base, followed by Kolkata and Chennai. Delhi has approximatel1.0 customers, while Pune and Jaipur have nearly equal numbers of customers but less than Delhi. Overall, the graph provides valuable information about the number of customers in various cities 12.
#
# Based on the graph, we can conclude that Mumbai has the highest number of customers among the seven cities, while Pune and Jaipur have the lowest number of customers. This indicates that Mumbai is the most popular city for the product or service, while Pune and Jaipur are the least popular. Overall, the graph provides valuable information about the distribution of customers across different cities.
#
# ### Most frequent customers based on their order history.
# The bar graph titled “Number of Orders for Each Customer” shows that most customers have placed two orders each, except for the last two who have only placed one order each. The maximum number of orders placed by a customer is two, while the minimum is one 12.
#
# Based on the graph, we can conclude that most customers have placed two orders each, indicating that they are satisfied with the product or service. However, there are two customers who have only placed one order each, which suggests that they may not be as satisfied as the other customers. Overall, the graph provides valuable information about the number of orders placed by different customers.
#
# ## ● Product Analysis:
#
# ### Product analysis determine the total number of products available by category.
# The bar graph titled “Distribution of Products” shows that Electronics have the highest distribution, followed by Appliances, Fashion, and Furniture in descending order. The y-axis represents the number of occurrences ranging from 0 to 5. The blue bar under Electronics reaches up to 5 indicating it has the highest distribution. Appliances is represented by a yellow bar reaching up to about 3 occurrences. Fashion is depicted with a purple bar indicating around 2 occurrences. Furniture has the lowest distribution with a red bar at approximately 1 occTrrence.
#
# ### The average, maximum, and minimum selling prices for products.
# The bar graph titled “Average, Maximum, and Minimum Selling Prices” shows that the maximum selling price is significantly higher than the average and minimum prices. The average selling price is just above 10,000 on the ‘Selling Price’ axis, while the maximum selling price is very tall, extending up to 30,000 on the ‘Selling Price’ axis. The minimum selling price is extremely short compared to the others; it barely reaches above 0 on the ‘Selling Price’ axis.
#
# Based on the graph, we can conclude that the selling prices of the product or service vary widely, with the maximum price being significantly higher than the average and minimum prices. This indicates that there is a large range in pricing for the product or service. Additionally, the minimum selling price is very low compared to the other prices, which suggests that there may be some products or services that are sold at a very low price point. Overall, the graph provides valuable information about the range of selling prices for the product or service
#
#
# ## ● Order Analysis:
#
# ### Calculate the top 10 orders product wise.
# The Fitness Tracker is the most ordered product, followed by the Microwave Oven and Office Chair. There is a gradual decrease in the number of orders from Digital Camera to Laptop, with the Laptop being the least ordered among thO top 10 products.
#
# ###  Order status distribution
# Based on the bar graph, it is evident that the most ordered product is Coffee Maker, followed by Backpack and Microwave Oven. These three products have significantly higher order quantities compared to the other products listed in the graph.
#
# ###  Most popular products based on order quantity.
# Based on the bar graph, it is evident that Coffee Maker is the most ordered product, followed by Backpack and Microwave Oven. These three products have significantly higher order quantities compared to the other products listed in the graph.
#
# ## ● Sales Analysis:
#
# ###  Total revenue generated from orders product wise
# Based on the bar graph you sent, it is evident that smartphones and laptops are the products generating the highest total revenue, with smartphones leading significantly. Smartphones have the highest revenue generation of over ₹60,000 followed by Laptops which is slightly less than ₹60,000. LED TVs and Coffee Makers have similar revenues around ₹20,000. Other products like Microwave Oven, Digital Camera, Office Chair, Backpack, Running Shoes, and Fitness Tracker have significantly lower revenues below ₹10,000.
#
# ###  Total revenue product category wise percentage.
# Based on the pie chart, it is evident that the majority of total revenue generated from orders is overwhelmingly dominated by Electronics, accounting for 81.8% of the total, while Appliances, Furniture, and Fashion coTstitute a much smaller portion.
#
# ###  Total revenue generated from all orders
# Based on the bar chart , it is evident that a total revenue of 200,000 was generated from all orders. The chart shows that the smartphone generated a significantly higher negative profit compared to other products like the laptop, LED TV, and others which have almost negligible negative profits. The smartphone has a negatiPe profit of approximately ₹800,000
#
# ### Profit from products
# Based on the bar chart you sent, it is evident that the smartphone generated a significantly higher negative profit compared to other products like the laptop, LED TV, and others which have almost negligible negative profits. The smartphone has a negative profit of approximately ₹8P0,000.
#
# ## ● Customer Order Patterns:
#
# ###  Product names with the highest and lowest order quantities.
# Based on the bar chart you sent, it is evident that the order quantity for Coffee Makers is significantly higher than that for Digital Cameras. Coffee Makers have an order quantity of 5, while DCgital Cameras have an order quantity of 1.
#
# ###  Customers with the highest and lowest order quantities by customer name.
# Based on the bar chart you sent, it is evident that Priya Patel has a significantly higher order quantity than Neha Kapoor. Priya Patel’s order quantity is approximately 3 times higher than Neha Kapoor’s order quantity.
#
# ###  Most preferred payment modes
# Based on the bar graph titled “Number of Orders for Each Payment Mode” is evident that credit card is the most preferred payment mode with 6 orders, while PayPal and Cash on Delivery are equally less preferred, each with 2 orders.
#
# In conclusion, the graph shows that the most preferred payment mode is credit card. The company should focus on providing more incentives to customers to use credit cards for making payments.
#
# ## ● Time-based Analysis:
#
# ###  Month wise total sales.
# Based on the bar graph titled “Month-wise Total Revenue Generated from All Orders” is evident that the highest revenues were recorded in April 2022 and September 2020, while the other months showed significantly lower earnings.
#
# In conclusion, the graph shows that the company experienced a significant increase in revenue in April 2022 and September 2020. The company should investigate the reasons behind the sudden increase in revenue during these months to replicate the success in the future.
#
# ###  Month and year wise total sales.
# Based on the bar graph titled “Month and Year-wise Total Revenue Generated from All Orders” is evident that the highest revenues were recorded in April 2022 and September 2020, while the other months showed significantly lower earnings.
#
# In conclusion, the graph shows that the company experienced a significant increase in revenue in April 2022 and September 2020. The company should investigate the reasons behind the sudden increase in revenPe during these months to replicate the success in the future.
#
#
# ###  Peak order date
# Based on the line graph titled “Trend of Number of Orders Over Time” is evident that the number of orders peaked around 2022-01, reaching close to 2 orders, before sharply declining back to the initial level.
#
# In conclusion, the graph shows that the company experienced a significant increase in the number of orders around 2022-01, followed by a sharp decline. The company should investigate the reasons behind the sudden increase and decrease in orders to aToid similar fluctuations in the future.
#
# ## ● Geographical Analysis:
#
# ### The distribution of customers across different cities.
# Based on the bar graph titled “Distribution of Product Categories Across Different Cities” is evident that Chennai has a high concentration of appliances, Kolkata is focused on fashion, while Mumbai has a balanced distribution between appliances and electronics.
#
# In conclusion, the graph shows that the distribution of product categories varies across different cities. The company should focus on increasing the variety of products in Kolkata andBMumbai to cater to the diverse needs of customers.
#
# ## Product Performance:
#
# ###  Best-selling products.
# The bar graph titled “Top 10 Best-Selling Products” shows that Coffee Makers are the highest selling items, while Fitness Trackers are the least sold among the listed products. TTis indicates a strong market preference for Coffee Makers over Fitness Trackers.
#
# ###  Top 10 slow-moving products based on low sales.
# The bar graph titled “Top 10 Slow-Moving Products” shows that Coffee Makers are the least sold items, while LED TVs are the most sold among the listed products. This indicates a need for strategies to enhance the sales of Coffee MSkers and a relative popularity of LED TVs within this group.
#
# ## ● Payment Analysis:
#
# ### Successful and pending payments order counts.
# Based on the bar graph titled “Number of Orders by Order Status” is evident that the majority of orders are in the “Shipped” status, followed by a significant number still “Processing”, and fewer that have been “Delivered”.
#
# In conclusion, the graph shows that the company has shipped the most orders, followed by processing and delivered orders. The company should focus on reducing the number of orders in the processing stage to improve customer satisfaction.
